# %%
# %pwd
# Out:
# 'C:\\Users\\ashish chandra'

# %%
# %cd E:\projects
# Out:
# E:\projects

# %%
# %pwd
# Out:
# 'E:\\projects'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
housing_df= pd.read_csv("E:\\Data Set\\housing_data1.csv")

# %%
housing_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469    NaN  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       499 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing_df['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  499.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.285002
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705809
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.627000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline
housing_df.hist(bins=50,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Train-test split

# %%
# def train_test_split(df,ratio):
#     shuffle=np.random.permutation(len(df))
#     test_size=int(len(df)*ratio)
#     test_set_ind=shuffle[:test_size]
#     train_set_ind=shuffle[test_size:]
#     return df.iloc[train_set_ind],df.iloc[test_set_ind]

# %%
#train_set,test_set=train_test_split(housing_df,0.2)

# %%
#print(f"rows in trainset:{len(train_set)}\nrows in test set:{len(test_set)}\n")

# %%
from sklearn.model_selection import train_test_split

train_set,test_set=train_test_split(housing_df,test_size=0.2,random_state=(42))

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=(42))
for train_index,test_index in split.split(housing_df,housing_df['CHAS'] ):
    stra_train_set=housing_df.loc[train_index]
    stra_test_set=housing_df.loc[test_index]
    print(stra_test_set)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 342   0.02498   0.0   1.89     0  0.518  6.540   59.7  6.2669    1  422
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666
# 223   0.61470   0.0   6.20     0  0.507  6.618   80.8  3.2721    8  307
# 219   0.11425   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 48    0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 88    0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270
# 466   3.77498   0.0  18.10     0  0.655  5.952   84.7  2.8715   24  666
# 52    0.05360  21.0   5.64     0  0.439  6.511   21.1  6.8147    4  243
# 121   0.07165   0.0  25.65     0  0.581  6.004   84.1  2.1974    2  188
# 218   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 342     15.9  389.96   8.65  16.5
# ...

# %%
stra_test_set['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
stra_train_set['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
95/7
# Out:
# 13.571428571428571

# %%
376/28
# Out:
# 13.428571428571429

# %%
housing_df=stra_train_set.copy()

# %% [markdown]
# # finding correlation

# %%
corr_matrix=housing_df.corr()

# %%
corr_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.212927  0.416640 -0.061482  0.430879 -0.258499  0.361890
# ZN      -0.212927  1.000000 -0.542161 -0.023536 -0.509327  0.297328 -0.565680
# INDUS    0.416640 -0.542161  1.000000  0.043686  0.759051 -0.385043  0.644114
# CHAS    -0.061482 -0.023536  0.043686  1.000000  0.077490  0.100417  0.058388
# NOX      0.430879 -0.509327  0.759051  0.077490  1.000000 -0.303748  0.727358
# RM      -0.258499  0.297328 -0.385043  0.100417 -0.303748  1.000000 -0.247897
# AGE      0.361890 -0.565680  0.644114  0.058388  0.727358 -0.247897  1.000000
# DIS     -0.386900  0.666939 -0.708612 -0.088081 -0.763623  0.210975 -0.734827
# RAD      0.648221 -0.306480  0.580908 -0.023005  0.596012 -0.198908  0.449489
# TAX      0.603934 -0.322803  0.716288 -0.048802  0.659049 -0.282078  0.501491
# PTRATIO  0.305603 -0.390570  0.384465 -0.132682  0.164977 -0.330807  0.259633
# ...

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.678838
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
att=['MEDV','RM','ZN','LSTAT']
scatter_matrix(housing_df[att],figsize=(16,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing_df.plot(kind='scatter',x='RM',y="MEDV",alpha=0.7)
#housing_df.plot(kind='box',x='MEDV',y="RM")
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %%
housing_df['TAXRM']=housing_df['TAX']/housing_df['RM']

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.678838
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing_df.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
corr_matrix=housing_df.corr()
corr_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.212927  0.416640 -0.061482  0.430879 -0.258499  0.361890
# ZN      -0.212927  1.000000 -0.542161 -0.023536 -0.509327  0.297328 -0.565680
# INDUS    0.416640 -0.542161  1.000000  0.043686  0.759051 -0.385043  0.644114
# CHAS    -0.061482 -0.023536  0.043686  1.000000  0.077490  0.100417  0.058388
# NOX      0.430879 -0.509327  0.759051  0.077490  1.000000 -0.303748  0.727358
# RM      -0.258499  0.297328 -0.385043  0.100417 -0.303748  1.000000 -0.247897
# AGE      0.361890 -0.565680  0.644114  0.058388  0.727358 -0.247897  1.000000
# DIS     -0.386900  0.666939 -0.708612 -0.088081 -0.763623  0.210975 -0.734827
# RAD      0.648221 -0.306480  0.580908 -0.023005  0.596012 -0.198908  0.449489
# TAX      0.603934 -0.322803  0.716288 -0.048802  0.659049 -0.282078  0.501491
# PTRATIO  0.305603 -0.390570  0.384465 -0.132682  0.164977 -0.330807  0.259633
# ...

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.678838
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.524633
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
"""removing missing values :=
1)get rid of missing data
2)get rid of whole attribute
3)impute the missing data with mean/median/mode  """
# Out:
# 'removing missing values :=\n1)get rid of missing data\n2)get rid of whole attribute\n3)impute the missing data with mean/median/mode  '

# %% [markdown]
# # filling missing data

# %%
a=housing_df.dropna(subset=['RM'])
a.shape#option 1 := droping na from the attribute
# Out:
# (398, 15)

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404 entries, 254 to 216
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    int64
#  4   NOX      404 non-null    float64
#  5   RM       398 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    int64
#  9   TAX      404 non-null    int64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  MEDV     404 non-null    float64
#  14  TAXRM    398 non-null    float64
# dtypes: float64(12), int64(3)
# memory usage: 50.5 KB

# %%
housing_df.drop(['RM'],axis=1)# option 2:= droping the rm column from the atributes
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD  TAX  PTRATIO  \
# 254  0.04819  80.0   3.64     0  0.392  32.0  9.2203    1  315     16.4
# 348  0.01501  80.0   2.01     0  0.435  29.7  8.3440    4  280     17.0
# 476  4.87141   0.0  18.10     0  0.614  93.6  2.3053   24  666     20.2
# 321  0.18159   0.0   7.38     0  0.493  54.3  4.5404    5  287     19.6
# 326  0.30347   0.0   7.38     0  0.493  28.9  5.4159    5  287     19.6
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 155  3.53501   0.0  19.58     1  0.871  82.6  1.7455    5  403     14.7
# 423  7.05042   0.0  18.10     0  0.614  85.1  2.0218   24  666     20.2
# 98   0.08187   0.0   2.89     0  0.445  36.9  3.4952    2  276     18.0
# 455  4.75237   0.0  18.10     0  0.713  86.5  2.4358   24  666     20.2
# 216  0.04560   0.0  13.89     1  0.550  56.0  3.1121    5  276     16.4
#
#           B  LSTAT  MEDV       TAXRM
# 254  392.89   6.57  21.9   51.571709
# ...

# %%
median=housing_df['RM'].median()

# %%
housing_df['RM'].fillna(median)       #option 3 filling with mdeian
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  398.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279947
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.716249
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.876000
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630750
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
# to replace null values for online pipeline data using median_imputation() we can use SimpleImputer from impute class

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='median')
imputer.fit(housing_df)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_.shape
# Out:
# (15,)

# %%
x=imputer.transform(housing_df)

# %%
housing_tr=pd.DataFrame(x,columns=housing_df.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278908
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.710948
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086963    0.000000    5.190000    0.000000    0.453000    5.879750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
# %pwd
# Out:
# 'E:\\projects'

# %% [markdown]
# # creating pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

# %%
housing_num=my_pipeline.fit_transform(housing_df)
